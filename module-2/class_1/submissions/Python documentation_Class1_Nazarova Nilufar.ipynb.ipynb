# %% [markdown]
# # Python Warmup -- Module 2, Class 1
#
# This notebook covers the Python fundamentals you need for data work:
# - Variables and data types
# - Functions
# - Loops
#
# Each section has examples first, then TODO exercises for you to complete.

# %% [markdown]
# # Python Warm-Up Documentation

# %% [markdown]
# ---
# ## 1. Variables and Data Types
#
# Python has four core data types you will use constantly:
# - **int** -- whole numbers (subscriber count, age)
# - **float** -- decimal numbers (bill amount, accuracy)
# - **str** -- text (customer name, region)
# - **bool** -- True or False (is_active, payment_on_time)
# - **list** -- ordered collection (monthly bills, feature names)

# %% [markdown]
# ## Introduction to Data Types
#
# In Python, every value stored in a variable has a specific data type.
# A data type defines what kind of information the variable contains
# and what operations can be performed on it.
#
# Understanding data types is important because Python treats numbers,
# text, and logical values differently.
#
# The main built-in data types studied in this notebook are:
#
# - Integer (int)
# - Float (float)
# - String (str)
# - Boolean (bool)
# - List (list)
# - Tuple (tuple)
# - Set (set)
# - Dictionary (dict)

# %%
# --- EXAMPLES ---

# Integers
subscriber_count = 10_000_000
age = 25


# Floats
monthly_bill = 89_500.50
accuracy = 0.95

# Strings
customer_name = "Abdullayev Jasur"
region = "Tashkent"

# Booleans
is_active = True
payment_on_time = False

# Lists
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

# Check types
print(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")
print(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")
print(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")
print(f"is_active:        {is_active} (type: {type(is_active).__name__})")
print(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")
# Out:
# subscriber_count: 10000000 (type: int)
# monthly_bill:     89500.5 (type: float)
# customer_name:    Abdullayev Jasur (type: str)
# is_active:        True (type: bool)
# monthly_bills:    [85000, 92000, 78000, 95000, 88000] (type: list)

# %% [markdown]
# ## Integer Data Type (int)
#
# An integer represents whole numbers without decimal points.
# Integers can be positive, negative, or zero.
#
# Examples include counting values, IDs, quantities,
# or number of users.
#
# Characteristics:
# - No decimal values
# - Supports mathematical operations
# - Unlimited size in Python
#
# Example uses:
# - age of a person
# - number of students
# - product quantity

# %%
age = 20
students = 35
temperature = -5

# %% [markdown]
# ## Float Data Type (float)
#
# A float represents numbers that contain decimal points.
# Floats are used when precision or measurements are required.
#
# They are commonly used in financial calculations,
# scientific data, and probabilities.
#
# Characteristics:
# - Contains decimal numbers
# - Supports arithmetic calculations
# - Less precise than integers for very large calculations

# %%
price = 99.99
accuracy = 0.95
weight = 65.5

# %% [markdown]
# ## String Data Type (str)
#
# A string represents text data.
# Strings must be written inside quotation marks.
#
# Strings are used for names, addresses,
# messages, and any textual information.
#
# Characteristics:
# - Written using single or double quotes
# - Supports text operations such as joining and slicing
# - Immutable (cannot change individual characters)

# %%
name = "Ali"
city = "Tashkent"
message = "Welcome to Python"

# %% [markdown]
# ## Boolean Data Type (bool)
#
# Boolean values represent logical states.
# There are only two possible values:
#
# True  → condition is correct
# False → condition is incorrect
#
# Booleans are mainly used in decision making,
# conditions, and comparisons.

# %%
is_student = True
payment_completed = False

# %% [markdown]
# ## List Data Type (list)
#
# A list is a collection of multiple values stored
# inside square brackets.
#
# Lists allow storing different data types together.
# They are ordered and changeable.
#
# Characteristics:
# - Ordered collection
# - Allows duplicates
# - Mutable (can be modified)
# - Indexed starting from 0

# %%
numbers = [10, 20, 30]
names = ["Ali", "Sara", "John"]
mixed = [25, "Tashkent", True]

# %%
# --- List operations ---

# Access by index (0-based)
print(f"First bill: {monthly_bills[0]}")
print(f"Last bill:  {monthly_bills[-1]}")

# Slicing
print(f"First 3 bills: {monthly_bills[:3]}")

# Length
print(f"Number of bills: {len(monthly_bills)}")

# Append
monthly_bills.append(91000)
print(f"After append: {monthly_bills}")

# %% [markdown]
# ### Indexing in Lists
#
# Each element in a list has an index number.
# Python indexing always starts from 0.
#
# Index represents the position of an element.

# %%
numbers[0]
numbers[1]
numbers[2]
# Out:
# 30

# %% [markdown]
# ### List Slicing
#
# Slicing extracts a portion of a list.
#
# Syntax:
# list[start : stop]
#
# Start index is included.
# Stop index is excluded.

# %%
numbers[0:2]
numbers[:3]
numbers[1:]
# Out:
# [20, 30]

# %% [markdown]
# ### Length of a List
#
# The len() function counts how many elements exist
# inside the list.

# %%
len(numbers)
# Out:
# 3

# %% [markdown]
# #### append()
#
# The append() method adds one element to the end of a list.

# %%
numbers.append(50)

# %%
# --- TODO: Variables exercise ---
# Create variables for a telecom customer profile:

# TODO: Create an integer variable for the customer's age
customer_age = None

# TODO: Create a float variable for their monthly data usage in GB
data_usage_gb = None

# TODO: Create a string variable for their city
city = None

# TODO: Create a boolean for whether they have a contract (vs prepaid)
has_contract = None

# TODO: Create a list of their last 6 monthly bills (make up reasonable numbers in soum)
bills = None

# TODO: Print all variables with their types (follow the example pattern above)

# %%
# --- Variables exercise ---
# Create variables for a telecom customer profile:

# Integer variable for the customer's age
customer_age = 21

# Float variable for monthly data usage in GB
data_usage_gb = 18.5

# String variable for their city
city = "Tashkent"

# Boolean for whether they have a contract (True = contract, False = prepaid)
has_contract = True

# List of last 6 monthly bills (in soum)
bills = [45000, 47000, 50000, 52000, 49000, 51000]

# Print all variables with their types
print("Customer Age:", customer_age, "| Type:", type(customer_age))
print("Data Usage (GB):", data_usage_gb, "| Type:", type(data_usage_gb))
print("City:", city, "| Type:", type(city))
print("Has Contract:", has_contract, "| Type:", type(has_contract))
print("Bills:", bills, "| Type:", type(bills))
# Out:
# Customer Age: 21 | Type: <class 'int'>
# Data Usage (GB): 18.5 | Type: <class 'float'>
# City: Tashkent | Type: <class 'str'>
# Has Contract: True | Type: <class 'bool'>
# Bills: [45000, 47000, 50000, 52000, 49000, 51000] | Type: <class 'list'>

# %% [markdown]
# ---
# ## 2. Dictionaries
#
# A dictionary stores key-value pairs. Think of it as a single row in a database table -- keys are column names, values are the data.

# %%
# --- EXAMPLE ---

customer = {
    "id": "UZT-001234",
    "name": "Karimov Sherzod",
    "region": "Tashkent",
    "monthly_spend": 125000,
    "is_active": True,
    "plan": "Premium"
}

# Access values by key
print(f"Customer: {customer['name']}")
print(f"Region:   {customer['region']}")
print(f"Spend:    {customer['monthly_spend']} soum")

# Add a new key
customer["tenure_months"] = 24
print(f"\nFull record: {customer}")

# %%
# --- TODO: Dictionary exercise ---
# Create a dictionary representing a product from an e-commerce store
# Include at least 5 keys: name, category, price, quantity_sold, rating

# TODO: Create the product dictionary
product = None

# TODO: Print the product name and price

# TODO: Add a new key "discount" with a value between 0 and 1

# TODO: Print all keys using product.keys()

# %%
#Dictionary exercise
product = "laptop"

#Integers variable for product price
price = 23500

#Float variable for product price
discount = 0.15

product =  {"name": "laptop","price": 23500,"discount": 0.15}

# %% [markdown]
# ---
# ## 3. Functions
#
# Functions take inputs, perform an operation, and return an output. They let you write reusable, modular code.
#
# In ML, every step of a pipeline is typically a function: load_data(), clean_data(), train_model(), evaluate().

# %%
# --- EXAMPLE: calculate_average ---

def calculate_average(numbers):
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count

bills = [85000, 92000, 78000, 95000, 88000, 91000]
avg_bill = calculate_average(bills)
print(f"Average monthly bill: {avg_bill:,.0f} soum")

# %%
# --- EXAMPLE: function with multiple returns ---

def describe_bills(bills):
    """Return basic statistics for a list of bills."""
    avg = sum(bills) / len(bills)
    minimum = min(bills)
    maximum = max(bills)
    return avg, minimum, maximum

avg, low, high = describe_bills(bills)
print(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")

# %% [markdown]
# ###  Function
#
# A function is a reusable block of code that performs a specific task.
#
# - It helps avoid repeating code.
# - It makes programs organized and easier to read.
# - A function can take input, process it, and return output.
#
# 👉 Example:
# A function can calculate the average of numbers.
#
# ---
#
# ###  Parameters
#
# Parameters are variables inside a function definition.
#
# - They act as placeholders for input values.
# - They receive data when the function is called.
#
# 👉 Example:
# `numbers` in `calculate_average(numbers)` is a parameter.
#
# ---
#
# ###  Docstring
#
# A docstring is a string written inside a function to describe it.
#
# - It is written using triple quotes `""" """`
# - It explains what the function does
# - It does NOT affect program execution
# - It is used for documentation and understanding code
#
# 👉 Example:
# `"""Calculate the average of a list of numbers."""`
#
# ---
#
# ### sum() Function
#
# `sum()` is a built-in Python function.
#
# - It adds all numbers in a list.
# - It returns the total value.
#
# 👉 Example:
# `sum([2, 3, 5]) = 10`
#
# ---
#
# ###  len() Function
#
# `len()` is a built-in Python function.
#
# - It returns the number of elements in a list.
# - It tells how many items are stored.
#
# 👉 Example:
# `len([10, 20, 30]) = 3`
#
# ---
#
# ###  return Statement
#
# The `return` statement is used inside a function to send a result back.
#
# - It ends the function immediately.
# - It gives the output to where the function was called.
# - Without `return`, the function gives no usable result.
#
# 👉 Example:
# `return total / count`
#
# ---
#
# ###  List
#
# A list is a data structure that stores multiple values in one variable.
#
# - It is ordered (has index positions).
# - It can store numbers, strings, or mixed data.
# - It is written using square brackets `[]`.
#
# 👉 Example:
# `[85000, 92000, 78000]`
#
# ---
#
# ###  Function Call
#
# A function call is when we use a function.
#
# - It sends input values into the function.
# - It executes the function code.
# - It may return a result.
#
# 👉 Example:
# `calculate_average(bills)`
#
# ---
#
# ###  Variable Assignment
#
# Variable assignment is storing a value in a variable.
#
# - The result of a function can be stored.
# - The variable can be used later.
#
# 👉 Example:
# `avg_bill = calculate_average(bills)`
#
# ---
#
# ###  print() Function
#
# `print()` is used to display output on the screen.
#
# - It shows results to the user.
# - It is commonly used for testing and output.
#
# ---
#
# ###  f-string
#
# An f-string is a way to insert variables inside text.
#
# - It starts with `f""`
# - It allows dynamic values inside strings
#
# 👉 Example:
# `f"Average: {avg_bill}"`
#
# ---
#
# ### Number Formatting (:,.0f)
#
# This is used to format numbers inside f-strings.
#
# - `,` adds commas for readability
# - `.0f` removes decimal values (rounds number)
#
# 👉 Example:
# `88166.67 → 88,167`

# %%
# --- TODO: Write your own functions ---

# TODO 1: Write a function called `classify_customer` that takes monthly_spend as input
#         and returns:
#         - "premium" if spend > 150000
#         - "standard" if spend is between 50000 and 150000 (inclusive)
#         - "basic" if spend < 50000

def classify_customer(monthly_spend):
    # TODO: implement this function
    pass

# Test your function:
# print(classify_customer(200000))  # should print "premium"
# print(classify_customer(75000))   # should print "standard"
# print(classify_customer(30000))   # should print "basic"

# %%
# TODO 2: Write a function called `calculate_churn_rate` that takes two arguments:
#         - total_customers (int)
#         - churned_customers (int)
#         Returns the churn rate as a percentage (float).

def calculate_churn_rate(total_customers, churned_customers):
    # TODO: implement this function
    pass

# Test:
# print(calculate_churn_rate(10000, 350))  # should print 3.5

# %%
# Function to classify customer based on NEW spending rules
def classify_customer(monthly_spend):
    """
    Customer classification with updated spending limits.
    """

    if monthly_spend > 200000:
        return "premium"
    elif monthly_spend >= 80000:
        return "standard"
    else:
        return "basic"


# Testing
print(classify_customer(250000))  # premium
print(classify_customer(120000))  # standard
print(classify_customer(50000))   # basic
# Out:
# premium
# standard
# basic

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops let you repeat an operation across a collection. In data work, you iterate over rows, columns, files, or parameter values constantly.

# %%
# --- EXAMPLE: basic for loop ---

regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]

for region in regions:
    print(f"Processing data for: {region}")

# %% [markdown]
# ###  enumerate() Function (Index + Value)
#
# The `enumerate()` function is used when we need both the position (index) and the value of items in a list while looping.
#
# Normally, a loop gives only the value.
# `enumerate()` gives:
# - the index (position)
# - the item value
#
# ---
#
# ###  List Creation
#
# ```python
# monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]

# %%
# --- EXAMPLE: enumerate (index + value) ---
# enumerate gives you both the position and the value

monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]

for i, bill in enumerate(monthly_bills):
    print(f"Month {i + 1}: {bill:,} soum")

# %%
# --- EXAMPLE: loop with conditional ---

customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]

print("High-value customers (spend > 100,000):")
for c in customers:
    if c["spend"] > 100000:
        print(f"  {c['name']}: {c['spend']:,} soum")
# Out:
# High-value customers (spend > 100,000):
#   Alisher: 200,000 soum
#   Bobur: 120,000 soum
#   Rustam: 180,000 soum

# %%
# --- TODO: Loop exercises ---

# TODO 1: Using the `customers` list above, loop through and classify each customer
#         using your classify_customer function from Section 3.
#         Print: "Name: <name>, Tier: <tier>"

# Your code here:
customer = [{"name": "G'ulom", "spend" : 300000},
            {"name": "Osiyo", "spend" : 178000},
            {"name": "Nilufar", "spend" : 150000},
            {"name": "Madina", "spend" : 30000},
            ]
print("low-value customers (spend < 400000):")

for  c in customer:
    if c["spend"] < 400000:
          print(f" {c['name']}: {c['spend']:,} soum")
# Out:
# low-value customers (spend < 400000):
#  G'ulom: 300,000 soum
#  Osiyo: 178,000 soum
#  Nilufar: 150,000 soum
#  Madina: 30,000 soum

# %%
# TODO 3: Write a loop that computes the total and average of the scores list.
#         Do NOT use sum() or len() -- compute manually with a loop.
#         Print: "Total: <total>, Average: <average>"

# Your code here:
scores =[20, 56, 79, 85]

total = 0
count = 0

for score in scores:
    total += score
    count += 1

average = total / count

print(f"total: {total}, Average: {average}")
# Out:
# total: 240, Average: 60.0

# %% [markdown]
# ---
# ## 5. Putting It All Together
#
# Combine variables, functions, and loops to solve a mini data task.

# %%
# --- TODO: Final exercise ---
#
# You have a dataset of 8 customers (list of dictionaries).
# Write code that:
# 1. Loops through each customer
# 2. Classifies them into tiers (use classify_customer or write inline logic)
# 3. Counts how many customers are in each tier
# 4. Prints a summary: "Premium: X, Standard: Y, Basic: Z"

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

# Your code here:
# --- Final exercise solution ---

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

# Counters
premium = 0
standard = 0
basic = 0

# Loop through customers
for customer in customers_data:
    spend = customer["monthly_spend"]

    if spend > 150000:
        premium += 1
    elif spend >= 50000:
        standard += 1
    else:
        basic += 1

# Final summary
print(f"Premium: {premium}, Standard: {standard}, Basic: {basic}")
# Out:
# Premium: 3, Standard: 3, Basic: 2
