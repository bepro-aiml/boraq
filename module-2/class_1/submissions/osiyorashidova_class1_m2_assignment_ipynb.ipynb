# %%
print("hello, AI/ML")
# Out:
# hello, AI/ML

# %%
age=19                              #int
name="Osiyo"                        #str
gpa=4.5                             #decimal
is_student=True                     #bool
scores=[90, 89, 91, 88, 92]         #list

# %%
print(age, type(age))
print(name, type(name))
print(gpa, type(gpa))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 19 <class 'int'>
# Osiyo <class 'str'>
# 4.5 <class 'float'>
# True <class 'bool'>
# [90, 89, 91, 88, 92] <class 'list'>

# %%
def calculate_average(numbers):
  total=sum(numbers)
  count=len(numbers)
  return total/count

# %%
test1=[80, 90, 70, 85, 95]
test2=[55, 62, 48, 71]
print("average 1:", calculate_average(test1))
print("average 2:", calculate_average(test2))
# Out:
# average 1: 84.0
# average 2: 59.0

# %%
names=["diddy", "epstein", "trump", "hitler", "putin"]
for index, names in enumerate(names):
  print(f"index {index}: {name}")
# Out:
# index 0: Osiyo
# index 1: Osiyo
# index 2: Osiyo
# index 3: Osiyo
# index 4: Osiyo

# %%
import random
exam_scores=[random.randint(0, 100) for  _  in range(10)]
print("scores:", exam_scores)
# Out:
# scores: [86, 65, 11, 51, 14, 18, 43, 7, 19, 84]

# %%
avg=calculate_average(exam_scores)
print(f"class average: {avg:.1f}")
# Out:
# class average: 39.8

# %%
if avg>=60:
  print("Result: PASS")
else:
    print("Result: FAIL")
# Out:
# Result: FAIL
