# %%
print("Hello, AI/ML!")
# Out:
# Hello, AI/ML!

# %%
# Creating variables of different types
age = 20                # int
gpa = 3.7               # float
name = "Lylia"          # string
is_student = True       # boolean
scores = [85, 90, 78]   # list

# Printing values + types
print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 20 <class 'int'>
# 3.7 <class 'float'>
# Lylia <class 'str'>
# True <class 'bool'>
# [85, 90, 78] <class 'list'>

# %%
# Function to calculate average
def calculate_average(numbers):
    total = sum(numbers)
    count = len(numbers)
    return total / count

# Test lists
test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]

print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %%
cities = ["Tashkent", "Samarkand", "Bukhara", "Namangan", "Fergana"]

for index, city in enumerate(cities):
    print(f"Index {index}: {city}")
# Out:
# Index 0: Tashkent
# Index 1: Samarkand
# Index 2: Bukhara
# Index 3: Namangan
# Index 4: Fergana

# %%
import random

# Create 10 random exam scores
exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores:", exam_scores)

# Reusing function from Task 3
avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")

# Pass/Fail condition
if avg >= 60:
    print("Result: PASS")
else:
    print("Result: FAIL")
# Out:
# Scores: [64, 40, 1, 58, 39, 44, 58, 80, 57, 74]
# Class average: 51.5
# Result: FAIL
