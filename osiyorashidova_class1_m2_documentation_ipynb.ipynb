# %% [markdown]
# # Python Warmup -- Module 2, Class 1
#
# This notebook covers the Python fundamentals you need for data work:
# - Variables and data types
# - Functions
# - Loops
#
# Each section has examples first, then TODO exercises for you to complete.

# %% [markdown]
# ---
# ## 1. Variables and Data Types
#
# Python has four core data types you will use constantly:
# - **int** -- whole numbers (subscriber count, age)
# - **float** -- decimal numbers (bill amount, accuracy)
# - **str** -- text (customer name, region)
# - **bool** -- True or False (is_active, payment_on_time)
# - **list** -- ordered collection (monthly bills, feature names)

# %%
# --- EXAMPLES ---

# Integers
subscriber_count = 10_000_000
age = 25

Integers are non-decimal numbers that can be used in countig (1,2,3)
subscriber_count is the number of subscribers-10_000_000
age is the person's age-25
both are variable integers.

# Floats
monthly_bill = 89_500.50
accuracy = 0.95


Floats are numbers which contain decimals
monthly_bill is the monthly paymet each month
accuracy is how correct is the model in making predictions
both are decimals because they used decimal numbers, not whole ones.

# Strings
customer_name = "Abdullayev Jasur"
region = "Tashkent"

Strings are data types that are used to store texts in quotes " "
customer_name is the name of the customer as a text
region is a city or location
both are strings because they show texts, not numbers.

# Booleans
is_active = True
payment_on_time = False

Bools are the data types that can only have 2 options: true and false
is_active is showing whether something is active right now or not
payment_on_time is whether the payment is paid on time or delayed
both are bools as they have true and false options each.

# Lists
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

Lists are the collection of multiple values within one variable
monthly_bills are the list of payments that are made through months
regions are the collected texts indicating different city names
both are lists because they are stored together as one variable.

# Check types
print(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")
print(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")
print(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")
print(f"is_active:        {is_active} (type: {type(is_active).__name__})")
print(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")

This prints each variable and shows data types
print() is for showing the texts on screen as output
f"" allows combine variables and texts together
type() is to check the exact data type
_name_ is used to show only the name of the type, to make it easier to read

# %%
# --- List operations ---

# Access by index (0-based)
print(f"First bill: {monthly_bills[0]}")
print(f"Last bill:  {monthly_bills[-1]}")

Index is a position of an item in the list
monthly_bills(0) is the first bill in the line-85000.
*becuase index always startsfrom 0
monthly_bills(-1) is a negative index, maning it counts from end to start negtively
it is the last item, which is 88000.

# Slicing
print(f"First 3 bills: {monthly_bills[:3]}")

slicing means taking some part from a list.
monthly bills(3) means start from item 0 to 3
but the 3 is not included,so it'll be 0,1 and 2.

# Length
print(f"Number of bills: {len(monthly_bills)}")

len() means how many items are in the list.
here there are 5 itmes.

# Append
monthly_bills.append(91000)
print(f"After append: {monthly_bills}")

append means adding a new item to the end of the list
if the monthly bills append(91000),
we write the alrady existing monthly bills of 85000, 92000, 78000, 95000, 88000 and 91000 at the end.

# %%
# --- TODO: Variables exercise ---
# Create variables for a telecom customer profile:

# TODO: Create an integer variable for the customer's age
customer_age = 23

# TODO: Create a float variable for their monthly data usage in GB
data_usage_gb =35.0

# TODO: Create a string variable for their city
city = 'New York'

# TODO: Create a boolean for whether they have a contract (vs prepaid)
has_contract = True

# TODO: Create a list of their last 6 monthly bills (make up reasonable numbers in soum)
bills = (55000, 55000, 70000, 70000, 55000, 55000)

# TODO: Print all variables with their types (follow the example pattern above)

print(customer_age, type(customer_age))
print(data_usage_gb, type(data_usage_gb))
print(city, type(city))
print(has_contract, type(has_contract))
print(bills, type(bills)).

# %% [markdown]
# ---
# ## 2. Dictionaries
#
# A dictionary stores key-value pairs. Think of it as a single row in a database table -- keys are column names, values are the data.

# %%
# --- EXAMPLE ---

customer = {
    "id": "UZT-001234",
    "name": "Karimov Sherzod",
    "region": "Tashkent",
    "monthly_spend": 125000,
    "is_active": True,
    "plan": "Premium"}

    dictionary here means storing data by using keys.
    these id, name, region,etc. are called keys

# Access values by key
print(f"Customer: {customer['name']}")-this line gets the customr name from the dictionary
print(f"Region:   {customer['region']}")-getting customers' region from the dictionary
print(f"Spend:    {customer['monthly_spend']} soum")-this is accessing the value of monthly expenditure



# Add a new key
customer["tenure_months"] = 24-adding a new information/key for the dictionary
print(f"\nFull record: {customer}")

# %%
# --- TODO: Dictionary exercise ---
# Create a dictionary representing a product from an e-commerce store
# Include at least 5 keys: name, category, price, quantity_sold, rating

# TODO: Create the product dictionary
product = {
"name":"can't hurt me",
"category": "self-improvement",
"price": 60000,
"quantity_sold": 120,
"rating": 4.8 }

# TODO: Print the product name and price
print(product["name"])
print(product["price"])

# TODO: Add a new key "discount" with a value between 0 and 1

product["discount"]=0.2

# TODO: Print all keys using product.keys()

print(product.keys()).

# %% [markdown]
# ---
# ## 3. Functions
#
# Functions take inputs, perform an operation, and return an output. They let you write reusable, modular code.
#
# In ML, every step of a pipeline is typically a function: load_data(), clean_data(), train_model(), evaluate().

# %%
# --- EXAMPLE: calculate_average ---

def calculate_average(numbers):-finding the mean
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count

calculating the avarage numbers is called mean among the given numbers
the formmula for this is dividing the sum of numbers to their len().
the average/mean of these numbers is 88,000.

bills = [85000, 92000, 78000, 95000, 88000, 91000]
avg_bill = calculate_average(bills)
print(f"Average monthly bill: {avg_bill:,.0f} soum")

# %%
# --- EXAMPLE: function with multiple returns ---

def describe_bills(bills):-list of bills are taken as an input
    """Return basic statistics for a list of bills."""
    avg = sum(bills) / len(bills)-this line finds the mean by adding sumbers and dividing to len(bills)
    minimum = min(bills)-finds the smallest bill value
    maximum = max(bills)-finds the largest bill value
    return avg, minimum, maximum-returning multiple values together
avg, low, high = describe_bills(bills)-splitting them into variables
print(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")

# %%
# --- TODO: Write your own functions ---

# TODO 1: Write a function called `classify_customer` that takes monthly_spend as input
#         and returns:
#         - "premium" if spend > 150000
#         - "standard" if spend is between 50000 and 150000 (inclusive)
#         - "basic" if spend < 50000


def classify_customer(monthly_spend):
    # TODO: implement this function
    if monthly_spend>150000:
        return "premium"
    elif 50000-monthly_spend-150000:
        return "standard"
    else:
       return "basic"

# Test your function:
# print(classify_customer(200000))  # should print "premium"
# print(classify_customer(75000))   # should print "standard"
# print(classify_customer(30000))   # should print "basic"

# %%
# TODO 2: Write a function called `calculate_churn_rate` that takes two arguments:
#         - total_customers (int)-total number of customers
#         - churned_customers (int)-prediction of customer number who is leaving
#         Returns the churn rate as a percentage (float)-sending the final result of the chrn rate calculation

def calculate_churn_rate(total_customers, churned_customers):
    # TODO: implement this function
    churn_rate=(churned_customers/total_customers)*100
    return churn_rate
# Test:
# print(calculate_churn_rate(10000, 350))  # should print 3.5

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops let you repeat an operation across a collection. In data work, you iterate over rows, columns, files, or parameter values constantly.

# %%
# --- EXAMPLE: basic for loop ---

regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]-list of cities

for region in regions:
    print(f"Processing data for: {region}")
    this is a loop that goes through each region one by one from the list.

# %%
# --- EXAMPLE: enumerate (index + value) ---
# enumerate gives you both the position and the value

monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]
the payment for every month

for i, bill in enumerate(monthly_bills):
    print(f"Month {i + 1}: {bill:,} soum")

# %%
enumere refers to the loops that you get both index and value in a set.
e.g: print (i, fruit)
output: 0-apple, 1-banana, 2-mango

# %%
# --- EXAMPLE: loop with conditional ---

customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]

print("High-value customers (spend > 100,000):")
for c in customers:
    if c["spend"] > 100000:
        print(f"  {c['name']}: {c['spend']:,} soum")

# %%
The information is stored as list of dictionaries that contains keys of name and spending
the print is saying that they are interested in customers who spend over 100000
it checks the spending of custmers over 100000, and the customer is shown if they meet this condition
if the condition is true, it shows the customer name and spending

# %%
# --- TODO: Loop exercises ---

# TODO 1: Using the `customers` list above, loop through and classify each customer
#         using your classify_customer function from Section 3.
#         Print: "Name: <name>, Tier: <tier>"

# Your code here:

# %%
def classify_customer(spend):
if spend>150000:
  return "high"
elif spend>80000:
  return "medium"
else:
    return "low"

for c in customer:
  tier=classify_customers(c["spend"])
  print(f"name: {c["name"]}, tier: {tier}")

# %%
# TODO 2: Given the list of scores below, use enumerate to print each score
#         with its rank (starting from 1), and mark scores above 90 with " -- HIGH"
#
# Expected output:
#   Rank 1: 72
#   Rank 2: 95 -- HIGH
#   Rank 3: 88
#   ...

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

# Your code here:

# %%
for i, score in enumerate (scores):
  if score>95:
  print(f"rank{i+1}: {score}--high")
  else:
  print(f"rank {i+1}: {score}")

# %%
# TODO 3: Write a loop that computes the total and average of the scores list.
#         Do NOT use sum() or len() -- compute manually with a loop.
#         Print: "Total: <total>, Average: <average>"

# Your code here:

# %%
total:829
counts:10
average= total/count
print(f"total:{total}, avearge: {average}")

# %% [markdown]
# ---
# ## 5. Putting It All Together
#
# Combine variables, functions, and loops to solve a mini data task.

# %%
# --- TODO: Final exercise ---
#
# You have a dataset of 8 customers (list of dictionaries).
# Write code that:
# 1. Loops through each customer
# 2. Classifies them into tiers (use classify_customer or write inline logic)
# 3. Counts how many customers are in each tier
# 4. Prints a summary: "Premium: X, Standard: Y, Basic: Z"

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

# Your code here:

# %%
premium=0
standard=0
basic=0

for c in customers_data:
  spend=c["monthly_spend"]

if spend>150000:
premium+=1
elif spend>80000:
standard+=1
else:
  basic+=1
print(f"premium:{premium}, standard:{standard}, basic: {basic}")
